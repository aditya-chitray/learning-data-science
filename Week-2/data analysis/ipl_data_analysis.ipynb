# %% [markdown]
# ### IPL Auction Data Analysis

# %%
## import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## import dataset
df  =pd.read_csv("ipl_2023_auction_data.csv",index_col=)
df.head(2)
# Out:
#    Unnamed: 0  Player's List Base Price    TYPE  COST IN ₹ (CR.)  \
# 0           0    Shivam Mavi    4000000  BOWLER              6.0
# 1           1  Joshua Little    5000000  BOWLER              4.4
#
#    Cost IN $ (000) 2022 Squad            Team
# 0            720.0        KKR  Gujarat Titans
# 1            528.0        NaN  Gujarat Titans

# %%
## dropping first column
df.drop(['Unnamed: 0'],axis=1, inplace=True)
df.head(2)
# Out:
#    Player's List Base Price    TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0    Shivam Mavi    4000000  BOWLER              6.0            720.0
# 1  Joshua Little    5000000  BOWLER              4.4            528.0
#
#   2022 Squad            Team
# 0        KKR  Gujarat Titans
# 1        NaN  Gujarat Titans

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player's List    568 non-null    object
#  1   Base Price       568 non-null    object
#  2   TYPE             568 non-null    object
#  3   COST IN ₹ (CR.)  243 non-null    float64
#  4   Cost IN $ (000)  243 non-null    float64
#  5   2022 Squad       230 non-null    object
#  6   Team             568 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 31.2+ KB

# %%
df.describe(include='all').T
# Out:
#                  count unique          top freq       mean         std  min  \
# Player's List      568    565  Akash Singh    2        NaN         NaN  NaN
# Base Price         568     10      2000000  274        NaN         NaN  NaN
# TYPE               568      4  ALL-ROUNDER  213        NaN         NaN  NaN
# COST IN ₹ (CR.)  243.0    NaN          NaN  NaN   0.687243      2.5117  0.0
# Cost IN $ (000)  243.0    NaN          NaN  NaN  82.469136  301.404032  0.0
# 2022 Squad         230     10           MI   28        NaN         NaN  NaN
# Team               568     11       Unsold  325        NaN         NaN  NaN
#
#                  25%  50%   75%     max
# Player's List    NaN  NaN   NaN     NaN
# Base Price       NaN  NaN   NaN     NaN
# TYPE             NaN  NaN   NaN     NaN
# COST IN ₹ (CR.)  0.0  0.0   0.2    18.5
# Cost IN $ (000)  0.0  0.0  24.0  2220.0
# 2022 Squad       NaN  NaN   NaN     NaN
# Team             NaN  NaN   NaN     NaN

# %%
df.isnull().sum()
# Out:
# Player's List        0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    325
# Cost IN $ (000)    325
# 2022 Squad         338
# Team                 0
# dtype: int64

# %%
## "Which players are the most costliest buys?

# df.loc[df['COST IN ₹ (CR.)'].idxmax(),["Player's List"]]

## top 5 costliest players

# df.nlargest(3,'COST IN ₹ (CR.)',keep="all")["Player's List"]

## Which players were the cheapest buys this season and which team bought them?

# df.loc[df['COST IN ₹ (CR.)']>0].nsmallest(3,'COST IN ₹ (CR.)',keep="first")
# Out:
#     Player's List Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 6     Urvil Patel    2000000  WICKETKEEPER              0.2             24.0
# 29  Bhagath Varma    2000000   ALL-ROUNDER              0.2             24.0
# 30    Ajay Mandal    2000000   ALL-ROUNDER              0.2             24.0
#
#    2022 Squad                 Team
# 6         NaN       Gujarat Titans
# 29        CSK  Chennai Super Kings
# 30        NaN  Chennai Super Kings

# %%
## distribution of team wise total spent

plt.barh(df['Team'],df['COST IN ₹ (CR.)'])
plt.xlabel('COST IN ₹ (CR.)')
plt.ylabel('Teams')
# plt.bar_label
# Out:
# Text(0, 0.5, 'Teams')
